# %% [markdown]
# ![](https://international.udemedellin.edu.co/wp-content/uploads/2021/07/iteso.jpg)
# <center>
#
# <h3>Instituto Tecnológico y de Estudios Superiores de Occidente  (ITESO)</h3>
#
#
# <h1>Aplicación del Atractor de Lorenz en la Modelización del Cambio Climático</h1>
#
#
# <h3>Integrantes del equipo:
#
#
#     Andrea del Pilar Zamora Cortes     745838
#
#     Sebastián Daniel Cirkovic León      739903
#
#
#
#
#     Materia:
#
#
#     Simulación Matemática (O2023_MAF2869K)
#
#
#     Profesor:
#
#
#     Gabriel Alejandro Morales Ruiz
#
#
#     26 de novienbre de 2023
# </center>

# %% [markdown]
# ### Objetivo General:
#
# Desarrollar y analizar un modelo computacional basado en el Atractor de Lorenz para simular y visualizar patrones de variabilidad climática, con el fin de comprender cómo pequeñas variaciones en las condiciones iniciales pueden influir en la dinámica atmosférica y el clima.
#
# #### Objetivos Específicos:
#
# 1. **Comprender los Fundamentos del Atractor de Lorenz:** Estudiar y explicar las bases matemáticas y físicas del Atractor de Lorenz.
# 2. **Análisis de la Teoría del Caos en el Clima:** Investigar cómo el efecto mariposa y la teoría del caos se aplican al clima y sus variaciones.
# 3. **Modelización del Cambio Climático Utilizando el Atractor de Lorenz:** Desarrollar un modelo simplificado que utilice las ecuaciones del Atractor de Lorenz para simular aspectos del cambio climático.
#
# ### Modelo que Representa el Problema:
#
# El modelo estándar del Atractor de Lorenz consta de tres ecuaciones diferenciales ordinarias:
#
# $$\frac{dx}{dt}=\sigma \left(y-x\right)$$
# $$\frac{dy}{dt}=x\left(\rho -z\right)-y$$
# $$\frac{dz}{dt}=xy-\beta z$$
#
# Donde:
#
# $x,y,z$ representan los estados del sistema.
#
# $t$ representa el tiempo.
#
# $\sigma,\rho,\beta$ son parámetros constantes.
#
# ### Significado y Valor de los Parámetros
#
# $\sigma$ (Número de Prandtl): Relaciona la viscosidad y conductividad térmica del fluido. En la atmósfera, valores típicos están alrededor de 10.
#
# $\rho$ (Número de Rayleigh): Indica la fuerza de la convección térmica. Para la atmósfera, este valor puede variar significativamente dependiendo de factores como la humedad y la radiación solar.
#
# $\beta$: Proporcional a la razón geométrica de las celdas de convección. Este valor es generalmente menos de 1 en sistemas atmosféricos.

# %% [markdown]
# ### Simulación y visualización

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 96.0
sigma = 109.0
beta = 3.0 / 8.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [4.0, 4.0, 4.0]
t = np.arange(0.0, 100.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 16.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [4.0, 4.0, 4.0]
t = np.arange(0.0, 100.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 10.0
beta = 3.0 / 8.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 1.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 280.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 82.0
sigma = 10.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D

rho = 28.0
sigma = 11.0
beta = 8.0 / 3.0

def f(state, t):
    x, y, z = state  
    return sigma * (y - x), x * (rho - z) - y, x * y - beta * z  

state0 = [1.0, 1.0, 1.0]
t = np.arange(0.0, 40.0, 0.01)

states = odeint(f, state0, t)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(states[:, 0], states[:, 1], states[:, 2])
plt.show()

# %% [markdown]
# ### Conclusiones
#
# En conclusión, el Atractor de Lorenz es un fascinante ejemplo de cómo sistemas aparentemente simples, regidos por ecuaciones matemáticas claras, pueden exhibir un comportamiento extremadamente complejo y caótico. Las implicaciones de este fenómeno van más allá de la matemática y la física, ofreciendo insights valiosos en campos tan diversos como la meteorología, la ecología, la economía y, por supuesto, la modelización del cambio climático.
#
# En resumen, el Atractor de Lorenz no solo demuestra la belleza de las matemáticas en la descripción de fenómenos complejos, sino que también subraya la importancia de entender y respetar la naturaleza intrínsecamente impredecible de los sistemas caóticos en el mundo real.

# %% [markdown]
# ### Referencias
# - Atractor de Lorenz. (2023). En Wikipedia, la enciclopedia libre. https://es.wikipedia.org/w/index.php?title=Atractor_de_Lorenz&oldid=155206199
#
# - Cuánticos, C. (2016, octubre 3). El atractivo de Lorenz. Cuentos Cuánticos. https://cuentoscuanticos.wordpress.com/2016/10/03/el-atractivo-de-lorenz/
#
# - Número de Prandtl. (2022). En Wikipedia, la enciclopedia libre. https://es.wikipedia.org/w/index.php?title=N%C3%BAmero_de_Prandtl&oldid=146708854
#
# - Número de Rayleigh. (2022). En Wikipedia, la enciclopedia libre. https://es.wikipedia.org/w/index.php?title=N%C3%BAmero_de_Rayleigh&oldid=144380957
